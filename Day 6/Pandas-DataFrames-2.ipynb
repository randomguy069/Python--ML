# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
booldf = df > 0
booldf
# Out:
#        W      X      Y      Z
# A  False   True  False   True
# B   True  False  False   True
# C   True  False  False  False
# D   True  False   True   True
# E  False   True  False   True

# %%
df[booldf] #values where it was true and NaN where it was false
# Out:
#           W         X         Y         Z
# A       NaN  0.196800       NaN  0.000366
# B  1.025984       NaN       NaN  0.649826
# C  2.154846       NaN       NaN       NaN
# D  0.147027       NaN  0.558769  1.024810
# E       NaN  1.862864       NaN  0.610478

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df['W'] > 0 #values greater than 0 in column W
# Out:
# A    False
# B     True
# C     True
# D     True
# E    False
# Name: W, dtype: bool

# %%
df[df['W']  > 0] #returns row B,C,D because that's where condition df['W'] holds true
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df[df['Z'] < 0] #returns row C where column Z's value < 0
# Out:
#           W         X         Y         Z
# C  2.154846 -0.610259 -0.755325 -0.346419

# %%
resultdf = df[df['W'] > 0]
resultdf
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
resultdf['X']
# Out:
# B   -0.156598
# C   -0.610259
# D   -0.479448
# Name: X, dtype: float64

# %%
df[df['W'] > 0]['X'] #gives the same result as above
# Out:
# B   -0.156598
# C   -0.610259
# D   -0.479448
# Name: X, dtype: float64

# %%
df[df['W'] > 0][['X','Y']]
# Out:
#           X         Y
# B -0.156598 -0.031579
# C -0.610259 -0.755325
# D -0.479448  0.558769

# %%
boolser = df['W'] > 0
boolser
result = df[boolser]
result[['W','X']]
# Out:
#           W         X
# B  1.025984 -0.156598
# C  2.154846 -0.610259
# D  0.147027 -0.479448

# %%
df[(df['W'] > 0) & (df['Y'] > 0.5)] #returns row D where W > 0 and Y > 0.5
# Out:
#           W         X         Y        Z
# D  0.147027 -0.479448  0.558769  1.02481

# %%
df[(df['W'] > 0) | (df['Y'] > 0.5)] #returns row D where W > 0 and Y > 0.5
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df.reset_index() #resetting the index
# Out:
#   index         W         X         Y         Z
# 0     A -0.993263  0.196800 -1.136645  0.000366
# 1     B  1.025984 -0.156598 -0.031579  0.649826
# 2     C  2.154846 -0.610259 -0.755325 -0.346419
# 3     D  0.147027 -0.479448  0.558769  1.024810
# 4     E -0.925874  1.862864 -1.133817  0.610478

# %%
newind= 'KA TR AP GJ MH'.split()
newind
# Out:
# ['KA', 'TR', 'AP', 'GJ', 'MH']

# %%
df['States'] = newind

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.993263  0.196800 -1.136645  0.000366     KA
# B  1.025984 -0.156598 -0.031579  0.649826     TR
# C  2.154846 -0.610259 -0.755325 -0.346419     AP
# D  0.147027 -0.479448  0.558769  1.024810     GJ
# E -0.925874  1.862864 -1.133817  0.610478     MH

# %%
df.set_index('States') #setting a new Index
# Out:
#                W         X         Y         Z
# States
# KA     -0.993263  0.196800 -1.136645  0.000366
# TR      1.025984 -0.156598 -0.031579  0.649826
# AP      2.154846 -0.610259 -0.755325 -0.346419
# GJ      0.147027 -0.479448  0.558769  1.024810
# MH     -0.925874  1.862864 -1.133817  0.610478

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.993263  0.196800 -1.136645  0.000366     KA
# B  1.025984 -0.156598 -0.031579  0.649826     TR
# C  2.154846 -0.610259 -0.755325 -0.346419     AP
# D  0.147027 -0.479448  0.558769  1.024810     GJ
# E -0.925874  1.862864 -1.133817  0.610478     MH
